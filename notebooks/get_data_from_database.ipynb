# %%
# ! pip install psycopg2==2.9.7
# ! pip install pandas==2.0.3
# ! pip install matplotlib==3.7.2
# Out:
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/6d/f8/ff4acac6ea3f896146fd2a9f76dafb7c36973f2a329cae1d60a7c7252395/matplotlib-3.7.2-cp38-cp38-win_amd64.whl.metadata
#   Using cached matplotlib-3.7.2-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
# ...
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/b2/e5/6a7a6f2bdfcc0a235adf6f40be4f0ab5d23e65b766af1b2570c26b33d3b3/contourpy-1.1.0-cp38-cp38-win_amd64.whl.metadata
#   Using cached contourpy-1.1.0-cp38-cp38-win_amd64.whl.metadata (5.7 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/ef/1c/08385ebd1cb58e89e1d30616684b492153cab32849d67e21d27298df5ff6/fonttools-4.42.0-cp38-cp38-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/153.7 kB ? eta -:--:--
# ...

# %%
import psycopg2
import pandas as pd

# %%
conn = psycopg2.connect(database="vgp",
                        host="redlab-integration.neuroo.ai",
                        user="SA",
                        password="4xMp6PzEBf6YhJ7P",
                        port="8105")

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT table_name FROM information_schema.tables WHERE table_schema = 'public'")
table_names = cur.fetchall()
for table in table_names:
    print(table[0])
# Out:
# geography_columns
# geometry_columns
# spatial_ref_sys
# data_bicycle_path
# data_pedestrian_count
# data_traffic_alert
# data_traffic_jam
# execution
# param
# metric_city
# metric_district
# permissions
# ref_bicycle_path_type
# param_category
# ref_city
# ref_agglomeration
# ref_import_bicycle_path_type
# ref_import_pedestrian_count_type
# ref_import_traffic_type
# ref_pedestrian_count_type
# ref_traffic_alert_type
# ref_traffic_jam_type
# sas_bicycle_path
# sas_count_pedestrian
# sas_traffic_alert
# sas_traffic_jam
# ref_district
# roles
# tokens
# users_roles
# users
# tab
# tab_widget
# widget
# tab_widget_option
# widget_skeletons
# tabs
# widget_options
# widgets

# %%
query2 = "SELECT * FROM metric_city WHERE category = 'JAM_LENGTH'"
data2 = pd.read_sql_query(query2, conn)
data2
# Out:
# C:\Users\doros\AppData\Local\Temp\ipykernel_189172\1239548595.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data2 = pd.read_sql_query(query2, conn)
#           id    category          date_event    date_last_update source  \
# 0       1232  JAM_LENGTH 2023-06-05 06:45:02 2023-07-11 16:57:28   waze
# 1       1233  JAM_LENGTH 2023-06-23 12:17:14 2023-07-11 16:57:28   waze
# 2       1234  JAM_LENGTH 2023-06-30 02:46:47 2023-07-11 16:57:28   waze
# 3          6  JAM_LENGTH 2023-06-05 06:45:02 2023-07-11 13:27:18   waze
# 4          7  JAM_LENGTH 2023-06-23 12:17:14 2023-07-11 13:27:18   waze
# ...      ...         ...                 ...                 ...    ...
# 58751  77429  JAM_LENGTH 2023-07-25 15:52:54 2023-07-25 16:15:00   waze
# 58752  77430  JAM_LENGTH 2023-07-25 15:59:25 2023-07-25 16:15:00   waze
# ...

# %%
conn.close()
